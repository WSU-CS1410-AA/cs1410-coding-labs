# %% [markdown]
# # Coding Lab 01 — C++ Basics
#
# This lab covers how C++ programs are structured, how to declare variables and use types, and how to read input and produce formatted output.
#
# **What you need to do**
#
# - For every **✏️ PREDICT BEFORE YOU RUN** cell, double-click the cell
#   and type your prediction. Then **uncomment the compile and run commands**
#   in the cell below and run it. Make sure the output appears before moving on.
# - Complete every **🎯 CODING CHALLENGE** cell.
# - For every **📹 VIDEO ACTIVITY** section:
#     1. Run the cell below the header to watch the video in the notebook.
#     2. Read the activity description, then implement the program **and**
#        the extension in your own style.
#     3. In the **MY APPROACH** cell, describe two specific ways your
#        implementation differs from the one shown in the video,
#        not including the extension.
#
# **Submission**
#
# When you are done:
# 1. Go to **Runtime → Run All** and confirm all cells run without errors.
# 2. Go to **File → Download → Download .ipynb** to save the file.
# 3. Submit the downloaded `.ipynb` file to Canvas before **Saturday midnight
#    of the week this lab is released**.
#
# **IMPORTANT NOTE:** Use the **outline panel** in the Colab left sidebar
# (the bullet-list icon) to navigate sections and jump directly to any
# coding challenge or video activity.

# %% [markdown]
# ## C++ Programming Basics
#
# ## The Hello World program
# Here is the simplest C++ program. It contains only one function named `main`. This function does only one thing: it prints the string "Hello, World!" to the screen.

# %%
# %%writefile ex01-hello.cpp
#
# #include <iostream>
#
# int main(){
#   std::cout << "Hello, world!" << std::endl;
#
#   return 0;
# }

# %% [markdown]
# Here, we used the `std::cout` along with the **insertion operator** `<<` to output text (strings and numbers) to the console. We also used `std::endl` to output a line break. To use `std::cout`, we must first include the `<iostream>` header file.
#
# Notice the semicolon `;` at the end of the statement which signals the end of that statement. In C++ semicolons at the end of statements are **required**, and forgetting semicolons is a COMMON error that beginner programmers do.
#
# <br>
#
# ---
#
# **IMPORTANT NOTE ON HOW TO RUN C++ IN COLAB**:
# The top line `%%writefile ex01-hello.cpp` is not part of the program itself. When this cell runs, `%%writefile` instructs Colab to save the content below the first line into a file with the specified name (`ex01-hello.cpp`).
#
# To compile and test this program, we use the following commands, each preceded by the `!` symbol, which instructs Colab to execute them as shell commands.

# %%
# !g++ -std=c++20 ex01-hello.cpp -o hello-01
# !./hello-01

# %% [markdown]
# Notice the output of the program displayed underneath the cell above when it is run.
#
# The `g++` command compiles the `ex01-hello.cpp` file into an executable program named as specified after the `-o` flag. The `-std=` flag instructs the compiler to use the 2017 version (standard) of C++. Other values include `c++11`, `c++14`, and `c++20`.
#
# The final `./hello-01` command runs the newly created program.
#
# This pattern of using `%%writefile` and commands preceded by `!` will repeat throughout the notebooks whenever we write, compile, and run C++ programs in Colab.
#
# ---
# <br>

# %% [markdown]
# ## C++ does not care about white spaces (space, tabs, and new lines)
# C++ does not care much for white space (spaces, tabs, and new lines). So the above statement would still work if was written as:

# %%
# %%writefile ex02-hello.cpp
#
# #include <iostream>
#
# int main(){
#   std ::  cout <<                "Hello, world!" <<
#     std   ::   endl;
#
#   return 0;
# }

# %%
# !g++ -std=c++20 ex02-hello.cpp -o hello-02
# !./hello-02

# %% [markdown]
# ## 🎯 CODING CHALLENGE 1
#
# Write a complete program that reads two `double` values from the user,
# computes their **sum**, **difference**, **product**, and **quotient**,
# and prints each result on a separate labeled line.
#
# Use `setw()` from `<iomanip>` to right-align the numeric results so they
# line up neatly. Example output:
#
# ```
# Enter two numbers: 10 4
#        Sum: 14
# Difference:  6
#    Product: 40
#   Quotient: 2.5
# ```

# %%
# %%writefile ch01.cpp
#
# #include <iostream>
# #include <iomanip>
# using namespace std;
#
# int main() {
#     double a, b;
#     cout << "Enter two numbers: ";
#     cin >> a >> b;
#
#     // TODO: compute and print sum, difference, product, quotient
#     // Use setw() to align the results
#
#     return 0;
# }

# %%
# !g++ -std=c++20 ch01.cpp -o ch01
# !./ch01

# %% [markdown]
# ## Outputting new lines
# We can output new lines using both the manipulator `std::endl` or the character `'\n'`.

# %%
# %%writefile ex03-hello.cpp
#
# #include <iostream>
#
# int main(){
#   std::cout << "Hello, world!" << std::endl;
#   std::cout << "Good" << std::endl << "morning!" << std::endl;
#   std::cout << "Welcome\nto\nC++!!!";
#
#   return 0;
# }

# %%
# !g++ -std=c++20 ex03-hello.cpp -o hello-03
# !./hello-03

# %% [markdown]
# And we can chain as many output pieces to a single `std::cout` as possible. The statement below is equivalent to the the above three statements.

# %%
# %%writefile ex04-hello.cpp
#
# #include <iostream>
#
# int main(){
#   std::cout << "Hello, world!" << std::endl
#             << "Good" << std::endl << "morning!" << std::endl
#             << "Welcome\nto\nC++!!!";
#
#   return 0;
# }

# %%
# !g++ -std=c++20 ex04-hello.cpp -o hello-04
# !./hello-04

# %% [markdown]
# ## Comments
# Comments are notes you leave in your programs to explain how they work or should be used to yourself or to anyone who reads your code. When the compiler sees these comments, it ignores them.
#
# C++ supports two kinds of comments:
# * Single line comments which start with two forward slashes `//` until end of line
# ```cpp
# // single line comment; until end of line.
# ```
# * multi-line comments which start with forward slash star `/*` and ends with star forward slash `*/`.
# ```cpp
#  /*
#   multi-line comment; spans
#   one
#   or
#   more
#   lines.
#  */
# ```

# %% [markdown]
# ## Data types
# C++ programs work with data of many types. The most common data types are :
# * Integers like 1, 5, 10, -16: we use the keyword `int` to define integers.
# * Decimals such as .2, 5.3, 3.2: we use the keyword `double` to define double-precision decimals and the keyword `float` to define single-precision decimals. Use `double` for decimals unless you are told otherwise.
# * Characters: which are single letters or symbols written between single quotes, such as the letter `'A'`, the digit `'8'`, the symbol `'@'` the line break character `'\n'`, the tab character `'\t'`. We use the keyword `char` to define single characters.
# * Booleans which are either `true` or `false`. We use the keyword `bool` to define booleans.
# * Strings which are one or more characters between double quotes such as the `"hello world"` text or the name `"Sam"`. We use the class `string` to define strings, which requires including the `<string>` header file.
#
# We must use these data types to define variables.
#
# To define a variable, we start with the data type of the variable followed by its name:
#
# ```cpp
#   <data-type> <variable-name>;
# ```
#
# Optionally we can initialize the variable at the time of its creation by providing an initial value in two ways:
#
#
# ```cpp
#   <data-type> <variable-name> = <initial-value>;
# ```
#
# or
#
# ```cpp
#   <data-type> <variable-name> { <initial-value> };
# ```
#
#
# Below are example variable definitions: some are initialized; others are not.

# %%
# %%writefile ex05-vars.cpp
#
# #include <iostream>
# #include <string> // For the string variables
#
# using namespace std;
#
# int main(){
#   int number;
#   double pi = 3.14;
#   char letter;
#   bool active = true;
#   float half { 0.5f }; // the f in 0.5f is for float
#   string message = "Good morning!";
#   char vowel { 'i' };
#   bool married { false };
#
#   return 0;
# }

# %%
# !g++ -std=c++20 ex05-vars.cpp -o vars
# !./vars

# %% [markdown]
# As the examples above show, variable names must be valid **C++ identifiers**. That means they:
# * can only contain letters, digits, and underscores,
# * cannot start with a digit, and
# * cannot be a C++ keyword.
#
# And you must always remember that:
# * **a variable must be defined before it can be used**
# * **it can only be defined once**.
#
# Try running the code cell above again. Do you see the error?

# %% [markdown]
# ## Reading input from the console
#
# And just like we used `cout` with the **insertion** `<<` operator to output to the console, we can use `cin` to read input data from the keyboard. To do that, we must first define a variable with the same data type as the input value.
#
# Here is an example of reading two integer values. Run it and enter two integers.

# %%
# %%writefile ex06-input.cpp
#
# #include <iostream>
#
# using namespace std;
#
# int main(){
#   int x, y;
#   cout << "Enter two integers: ";
#   cin >> x >> y;
#
#   cout << x << '\t' << y << endl;
#
#   return 0;
# }

# %%
# !g++ -std=c++20 ex06-input.cpp -o input-01
# !./input-01

# %% [markdown]
# Notice the use of:
# ```cpp
# cout << x << '\t' << y << endl;
# ```
#
# for displaying the values you entered.

# %% [markdown]
# Similarly to receive `double` input, we define a `double` variable. And we then take the entered fahrenheit temperature and convert it into celsius using the formula:
#
# $C = (F - 32) \times \frac{5}{9}$

# %%
# %%writefile ex07-temp.cpp
#
# #include <iostream>
#
# using namespace std;
#
# int main(){
#   double f_temp; // To be entered
#   double c_temp; // To be calculated
#
#   // Input
#   cout << "Temperature in fahrenheit:\n";
#   cin >> f_temp;
#
#   // Output
#   c_temp = (f_temp - 32) * 5.0 / 9.0;
#   cout << "Temperature in Celsius is: " << c_temp << '\n';
#
#   return 0;
# }

# %%
# !g++ -std=c++20 ex07-temp.cpp -o temp
# !./temp

# %% [markdown]
# ## 🎯 CODING CHALLENGE 3
# Finish, compile and run the program below. It should prompt the user to enter the radius of a circle and read it into a `double` variable named `radius`. Calculate and display the area of a circle with that radius.

# %%
# %%writefile ch03.cpp
#
# #include <iostream>
#
# using namespace std;
#
# int main(){
#   const double PI = 3.14159;
#
#   // TODO
#
#   return 0;
# }

# %%
# !g++ -std=c++20 ch05.cpp -o ch05
# !./ch05

# %% [markdown]
# In the challenge above, we needed the value of $\pi$ (`PI`) which is a constant whose value is 3.14159. And by convention, constants' names are ALL CAPS.

# %% [markdown]
# ---
# ## 📹 VIDEO ACTIVITY 1 — Temperature Conversion

# %%
from IPython.display import IFrame
IFrame(src="https://1533221.mediaspace.kaltura.com/embed/secure/iframe/entryId/1_8ddzgap3/uiConfId/52196452/st/0", width=1024, height=576)

# %% [markdown]
# <a href="https://1533221.mediaspace.kaltura.com/media/t/1_8ddzgap3">Open video in new tab</a>

# %% [markdown]
# The video implements a program that reads a temperature in Celsius and converts it to
# Fahrenheit using the formula `F = 9.0 * C / 5.0 + 32`.
#
# Implement your own version that reads a Celsius value and prints the equivalent
# Fahrenheit temperature.
#
# **Then extend it:** Add a second conversion from Fahrenheit to Kelvin using `K = F + 459.67`.
# Print all three values (Celsius, Fahrenheit, Kelvin) labeled and aligned.

# %%
# %%writefile act0101.cpp
#
# // TODO: implement in your own style

# %%
# !g++ -std=c++20 act0101.cpp -o act0101
# !./act0101

# %% [markdown]
# **MY APPROACH:** *(Double-click this cell and describe two specific ways your implementation differs from the one shown in the video, not including the extension.)*

# %% [markdown]
# ---

# %% [markdown]
# ## Type Inference with `auto`
#
# C++11 introduced the `auto` keyword, which lets the compiler deduce a variable's
# type from its initializer. You will use `auto` constantly throughout this course —
# especially with iterators, range-based for loops, and complex return types.

# %%
# %%writefile ex_auto.cpp
#
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     auto count  = 10;          // compiler deduces int
#     auto pi     = 3.14159;     // compiler deduces double
#     auto letter = 'A';         // compiler deduces char
#     auto name   = string("Sam"); // compiler deduces string
#
#     cout << count  << "\n"
#          << pi     << "\n"
#          << letter << "\n"
#          << name   << "\n";
#
#     return 0;
# }

# %% [markdown]
# ---
# ### ✏️ PREDICT BEFORE YOU RUN
#
# Look at the code in the cell above. Before running the next cell, answer below:
#
# - What will this program output?
# - If it reads input, assume the user enters: *(write your assumption here)*
#
# **MY PREDICTION:** *(double-click to edit this cell — type your prediction between the two \`\`\` lines below)*
#
# ```
# Replace this line with your prediction
# ```
#
# Then **uncomment the compile and run commands** in the cell below and run it.
# Make sure the output appears before moving on.
#
# ---

# %%
# Uncomment to compile and run (do this after writing your prediction above):
# !g++ -std=c++20 ex_auto.cpp -o ex_auto
# !./ex_auto

# %% [markdown]
# `auto` does not make C++ dynamically typed. The type is still fixed at compile time —
# the compiler just figures it out so you don't have to write it. Use `auto` freely
# when the type is obvious from the right-hand side. Be explicit (write the type out)
# when clarity matters more than brevity.

# %% [markdown]
# ## 🎯 CODING CHALLENGE 4 — Using `auto`
#
# Rewrite the four variable declarations below **without** writing any explicit type
# names. Use `auto` for every variable. The program must compile and produce identical
# output.
#
# After you get it compiling, add a fifth `auto` variable of type `bool` initialized
# to `true` and print it. What does C++ print for a `bool`? Does it surprise you?

# %%
# %%writefile ch04b.cpp
#
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // TODO: rewrite each line using auto instead of the explicit type
#     int    quantity  = 5;
#     double price     = 9.99;
#     char   grade     = 'B';
#     string item      = string("Notebook");
#
#     cout << quantity << "\n"
#          << price    << "\n"
#          << grade    << "\n"
#          << item     << "\n";
#
#     // TODO: add a bool variable using auto, print it
#
#     return 0;
# }

# %%
# !g++ -std=c++20 ch04b.cpp -o ch04b
# !./ch04b

# %% [markdown]
# ## Arithmetic operators
# C++ supports multiple arithmetic operators( +, -, \*, /) representing addition, subtraction, multiplication, and division respectively. We use these operators to create expressions like:

# %%
# %%writefile ex08-arithmetic.cpp
#
# #include <iostream>
#
# using namespace std;
#
# int main(){
#   int x = 10;
#
#   cout << 6 + 7   << endl
#        << x - 5   << endl
#        << 4 * 3   << endl
#        << 7 / 2   << endl    // Integer division
#        << 7 % 2   << endl    // Remainder
#        << 7 / 2.0 << endl;
#
#   return 0;
# }

# %% [markdown]
# ---
# ### ✏️ PREDICT BEFORE YOU RUN
#
# Look at the code in the cell above. Before running the next cell, answer below:
#
# - What will this program output?
# - If it reads input, assume the user enters: *(write your assumption here)*
#
# **MY PREDICTION:** *(double-click to edit this cell — type your prediction between the two \`\`\` lines below)*
#
# ```
# Replace this line with your prediction
# ```
#
# Then **uncomment the compile and run commands** in the cell below and run it.
# Make sure the output appears before moving on.
#
# ---

# %%
# Uncomment to compile and run (do this after writing your prediction above):
# !g++ -std=c++20 ex08-arithmetic.cpp -o arithmetic
# !./arithmetic

# %% [markdown]
# ---
# ## 📹 VIDEO ACTIVITY 2 — Two-Number Arithmetic

# %%
from IPython.display import IFrame
IFrame(src="https://1533221.mediaspace.kaltura.com/embed/secure/iframe/entryId/1_wp684vpg/uiConfId/52196452/st/0", width=1024, height=576)

# %% [markdown]
# <a href="https://1533221.mediaspace.kaltura.com/media/t/1_wp684vpg" target="_blank">Open video in new tab</a>

# %% [markdown]
# The video implements a program that reads two integers from the user and prints their
# sum, difference, product, and integer quotient — one result per line, each labeled.
#
# Implement your own version that reads two integers `x` and `y` and produces the same
# four results.
#
# **Then extend it:** Add two more output lines — one for integer remainder (`x % y`) and one
# for floating-point division (`(double)x / y`). What is `17 % 5`? What is `(double)17 / 5`?
# Did both results match your expectation?

# %%
# %%writefile act0102.cpp
#
# // TODO: implement in your own style

# %%
# !g++ -std=c++20 act0102.cpp -o act0102
# !./act0102

# %% [markdown]
# **MY APPROACH:** *(Double-click this cell and describe two specific ways your implementation differs from the one shown in the video, not including the extension.)*

# %% [markdown]
# ---

# %% [markdown]
# ## Relational operators
# C++ also support relational operators which are used to compare two values and see if one is >, <, >=, <=, == (equal to), and != (not equal to) the other. These operators return boolean values that evaluate to either `true` or `false`. For example `6 < 7` is true but `2 >= 7` is false.
#
# **Note**: We always use two equal signs `==` to check if one value is equal to another. One equal sign `=` means assignment, not equality.

# %%
# %%writefile ex09-relational.cpp
#
# #include <iostream>
#
# using namespace std;
#
# int main(){
#   cout << (6.5 < 7) << endl
#        << ('a' > 'z') << endl
#        << (4 >= 3) << endl
#        << (2 <= 7) << endl
#        << (9 == 9) << endl
#        << ('x' != 'X') << endl
#        << (7.1 == 2.0) << endl;
#
#   return 0;
# }

# %% [markdown]
# ---
# ### ✏️ PREDICT BEFORE YOU RUN
#
# Look at the code in the cell above. Before running the next cell, answer below:
#
# - What will this program output?
# - If it reads input, assume the user enters: *(write your assumption here)*
#
# **MY PREDICTION:** *(double-click to edit this cell — type your prediction between the two \`\`\` lines below)*
#
# ```
# Replace this line with your prediction
# ```
#
# Then **uncomment the compile and run commands** in the cell below and run it.
# Make sure the output appears before moving on.
#
# ---

# %%
# Uncomment to compile and run (do this after writing your prediction above):
# !g++ -std=c++20 ex09-relational.cpp -o relational
# !./relational

# %% [markdown]
# Notice how `true` is printed as `1` and `false` as `0` by the `cout` output statement.

# %% [markdown]
# ## Logical operators
# C++ also allows us to combine multiple boolean expressions using the `&&` (AND) operator or the `||` (OR) operator, or negate a boolean expression using the `!` (NOT) operator. These are called logical operators and like relational operators, they evaluate to either `true` or `false`.
#
# Here’s is a truth table showing when the resutls of these operations are true and when they are false.
#
# | A   | B   | A AND B | A OR B  |
# | --- | --- | -------: | -------: |
# | True   | True   | True       | True       |
# | True   | False   | False       | True       |
# | False   | True   | False       | True       |
# | False   | False   | False       | False       |
#
#
# Here is an example

# %%
# %%writefile ex10-logical.cpp
#
# #include <iostream>
#
# using namespace std;
#
# int main(){
#   int x = 16;
#
#   cout << (x < 7 || x > 5) << endl;
#   cout << (x != 5 && x != 7) << endl;
#   cout << !true << endl;
#   cout << !false << endl;
#   cout << !(!(true)) << endl;
#
#   return 0;
# }

# %% [markdown]
# ---
# ### ✏️ PREDICT BEFORE YOU RUN
#
# Look at the code in the cell above. Before running the next cell, answer below:
#
# - What will this program output?
# - If it reads input, assume the user enters: *(write your assumption here)*
#
# **MY PREDICTION:** *(double-click to edit this cell — type your prediction between the two \`\`\` lines below)*
#
# ```
# Replace this line with your prediction
# ```
#
# Then **uncomment the compile and run commands** in the cell below and run it.
# Make sure the output appears before moving on.
#
# ---

# %%
# Uncomment to compile and run (do this after writing your prediction above):
# !g++ -std=c++20 ex10-logical.cpp -o logical
# !./logical

# %% [markdown]
# ## Assignment operators
# We also have the assignment operators. In its simplest form, the single equal sign `=` is used to assign the value on the right hand side to the variable on the left hand side. And because assignments are full statements, they must have `;` at the end.
#
# For example:
#
# ```cpp
# x = 14;
# y = y + x - 7;
# ```

# %% [markdown]
# ## 🎯 CODING CHALLENGE 7 — Compound Assignments
#
# Write a program that starts with `int total = 1` and applies **five**
# compound assignment operations of your choice (`+=`, `-=`, `*=`, `/=`, `%=`)
# to transform it. Print `total` after **each** operation with a label.
#
# Then, in a comment block at the bottom of the file, answer:
#
# > *"If I changed `total` to `double total = 1.0`, which operations would
# >  produce different results, and why?"*

# %%
# %%writefile ch07.cpp
#
# #include <iostream>
# using namespace std;
#
# int main() {
#     int total = 1;
#
#     // Apply five compound assignment operations of your choice.
#     // Print total after each one.
#     // Example: total += 9; cout << "After +=9: " << total << "\n";
#
#     // TODO
#
#     return 0;
# }
#
# /*
#  * REFLECTION:
#  * If I changed total to double, which operations produce different results?
#  * Answer: ...
#  */

# %%
# !g++ -std=c++20 ch07.cpp -o ch07
# !./ch07

# %% [markdown]
# ## Increment/Decrement by one operators
# Finally, C++ supports the increment `++` and the decrement `--` operators. These operators increments or decrements the value of their variables by one. For example `x++` is the same as incrementing the value of `x` by `1` and similarly `x--` is like decrementing `x` by `1`. The same goes for `++x` and `--x`.
#
# But one must understand the difference between `++x` and `x++`. `++x` is called **prefix increment** which means `x` is incremented at the beginning of the statement, while`x++` is called **postfix increment** meaning that `x` is incremented at the end of the statement.
#
# Here is an example. Notice specifically outout of the second and fourth `cout` statements. Change all `++` to `--` and run it again. Does the output make sense?

# %%
# %%writefile ex11-increment.cpp
#
# #include <iostream>
#
# using namespace std;
#
# int main(){
#
#   //TODO
#   int count = 10;
#
#   cout << "count=" << count << endl;
#   cout << "count=" << ++count << endl;
#   cout << "count=" << count << endl;
#   cout << "count=" << count++ << endl;
#   cout << "count=" << count << endl;
#
#   return 0;
# }

# %% [markdown]
# ---
# ### ✏️ PREDICT BEFORE YOU RUN
#
# Look at the code in the cell above. Before running the next cell, answer below:
#
# - What will this program output?
# - If it reads input, assume the user enters: *(write your assumption here)*
#
# **MY PREDICTION:** *(double-click to edit this cell — type your prediction between the two \`\`\` lines below)*
#
# ```
# Replace this line with your prediction
# ```
#
# Then **uncomment the compile and run commands** in the cell below and run it.
# Make sure the output appears before moving on.
#
# ---

# %%
# Uncomment to compile and run (do this after writing your prediction above):
# !g++ -std=c++20 ex11-increment.cpp -o increment
# !./increment
